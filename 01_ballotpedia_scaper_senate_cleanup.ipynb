# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Get senatorial candidates from wmp using the latest file

# %%
s = pd.read_csv("../datasets/candidates/wmpcand_012523_wmpid.csv")

# %%
s.columns
# Out:
# Index(['wmpid', 'genelect_cd', 'CurrCand', 'cand_name', 'cand_id',
#        'cand_office', 'cand_office_st', 'cand_office_dist',
#        'cand_party_affiliation', 'cand_incumbent_challenger_open_s',
#        'dateadded_cd', 'office_wapo', 'result_wapo', 'primarydate_wapo',
#        'trumpe_wapo', 'gender_wmp', 'gender_crp', 'latino_wmp', 'latino_crp',
#        'race_wmp', 'race_crp1', 'race_crp2', 'race_crpmena', 'hse_cmpt_gen',
#        'full_name', 'first_name', 'last_name'],
#       dtype='object')

# %%
s.genelect_cd.value_counts(dropna=False)
# Out:
# 0    2929
# 1    1366
# Name: genelect_cd, dtype: int64

# %%
s = s.loc[(s['genelect_cd']==1)&(s['cand_office']=='S')]

# %%
s.shape
# Out:
# (173, 27)

# %%
s.head()
# Out:
#           wmpid  genelect_cd CurrCand            cand_name    cand_id  \
# 3613  WMPID1299            1        Y   BOOZMAN, SEN. JOHN  S0AR00150
# 3615  WMPID1302            1        Y          KELLY, MARK  S0AZ00350
# 3618  WMPID1305            1        Y   BENNET, MICHAEL F.  S0CO00211
# 3619  WMPID1315            1        Y  BLUMENTHAL, RICHARD  S0CT00177
# 3620  WMPID1321            1        Y         RUBIO, MARCO  S0FL00338
#
#      cand_office cand_office_st  cand_office_dist cand_party_affiliation  \
# 3613           S             AR               0.0                    REP
# 3615           S             AZ               0.0                    DEM
# 3618           S             CO               0.0                    DEM
# 3619           S             CT               0.0                    DEM
# 3620           S             FL               0.0                    REP
#
#      cand_incumbent_challenger_open_s  ... latino_wmp latino_crp  \
# 3613                        INCUMBENT  ...        NaN        NaN
# 3615                        INCUMBENT  ...        0.0          N
# 3618                        INCUMBENT  ...        0.0          N
# 3619                        INCUMBENT  ...        NaN        NaN
# 3620                        INCUMBENT  ...        1.0          Y
#
#              race_wmp race_crp1  race_crp2 race_crpmena hse_cmpt_gen  \
# 3613            White         W        NaN          NaN            0
# 3615            White         W        NaN            N            0
# 3618            White         W        NaN            N            0
# 3619            White         W        NaN          NaN            0
# 3620  Hispanic/Latino         H        NaN          NaN            0
#
#                full_name first_name   last_name
# 3613        John Boozman       John     Boozman
# 3615          Mark Kelly      Kelly        Mark
# 3618      Michael Bennet    Michael      Bennet
# 3619  Richard Blumenthal    Richard  Blumenthal
# 3620         Marco Rubio      Marco       Rubio
#
# [5 rows x 27 columns]

# %%
s = s[['wmpid', 'cand_name', 'full_name', 'cand_office_st', 'cand_party_affiliation']]

# %%
s.head()
# Out:
#           wmpid            cand_name           full_name cand_office_st  \
# 3613  WMPID1299   BOOZMAN, SEN. JOHN        John Boozman             AR
# 3615  WMPID1302          KELLY, MARK          Mark Kelly             AZ
# 3618  WMPID1305   BENNET, MICHAEL F.      Michael Bennet             CO
# 3619  WMPID1315  BLUMENTHAL, RICHARD  Richard Blumenthal             CT
# 3620  WMPID1321         RUBIO, MARCO         Marco Rubio             FL
#
#      cand_party_affiliation
# 3613                    REP
# 3615                    DEM
# 3618                    DEM
# 3619                    DEM
# 3620                    REP

# %%
len(s['wmpid'].unique())
# Out:
# 173

# %% [markdown]
# ### Load the data cleaned by by RA Jasmine
#
# Note:
# - Jasmine's clean-up is based on a previous scraping result which is slightly different from ./data/bp2022_sen_scraped_face.csv
# - wmpid was added to this file using both fuzzymatch and human coding

# %%
sen_c = pd.read_excel("./data/bp2022_sen_scraped_face_jasmine.xlsx")

# %%
sen_c.shape
# Out:
# (172, 20)

# %%
sen_c.head(2)
# Out:
#        wmpid           cand_name     full_name cand_office_st  \
# 0  WMPID1299  BOOZMAN, SEN. JOHN  John Boozman             AR
# 1  WMPID1302         KELLY, MARK    Mark Kelly             AZ
#
#   cand_party_affiliation       matches         bp_name_raw  \
# 0                    REP  John Boozman  John Boozman (R)
# 1                    DEM    Mark Kelly    Mark Kelly (D)
#
#                                               bp_url       bp_name  \
# 0  https://s3.amazonaws.com/ballotpedia-api4/file...  John Boozman
# 1  https://s3.amazonaws.com/ballotpedia-api4/file...    Mark Kelly
#
#           bp_url_filename _merge  hc_face_note hc_face_url hc_first_name  \
# 0  johnboozmanupdated.jpg   both           NaN         NaN           NaN
# 1          Mark-Kelly.png   both           NaN         NaN           NaN
#
#   hc_last_name hc_middle_name hc_suffix hc_affix  hc_name_other  \
# 0          NaN            NaN       NaN      NaN            NaN
# 1          NaN            NaN       NaN      NaN            NaN
#
#   hc_double_surname
# 0               NaN
# 1               NaN

# %% [markdown]
# Use Jasmine's urls when scraped bp_url is missing

# %%
sen_c['bp_face_url']= sen_c['bp_url']

# %%
sen_c['bp_face_url']=sen_c.apply(
    lambda row: row['hc_face_url'] if pd.isnull(row['bp_face_url']) else row['bp_face_url'],
    axis=1)

# %%
sen_c.head(2)
# Out:
#        wmpid           cand_name     full_name cand_office_st  \
# 0  WMPID1299  BOOZMAN, SEN. JOHN  John Boozman             AR
# 1  WMPID1302         KELLY, MARK    Mark Kelly             AZ
#
#   cand_party_affiliation       matches         bp_name_raw  \
# 0                    REP  John Boozman  John Boozman (R)
# 1                    DEM    Mark Kelly    Mark Kelly (D)
#
#                                               bp_url       bp_name  \
# 0  https://s3.amazonaws.com/ballotpedia-api4/file...  John Boozman
# 1  https://s3.amazonaws.com/ballotpedia-api4/file...    Mark Kelly
#
#           bp_url_filename  ... hc_face_note  hc_face_url hc_first_name  \
# 0  johnboozmanupdated.jpg  ...          NaN          NaN           NaN
# 1          Mark-Kelly.png  ...          NaN          NaN           NaN
#
#   hc_last_name hc_middle_name hc_suffix hc_affix hc_name_other  \
# 0          NaN            NaN       NaN      NaN           NaN
# 1          NaN            NaN       NaN      NaN           NaN
#
#    hc_double_surname                                        bp_face_url
# 0                NaN  https://s3.amazonaws.com/ballotpedia-api4/file...
# 1                NaN  https://s3.amazonaws.com/ballotpedia-api4/file...
#
# [2 rows x 21 columns]

# %%
sen_c.loc[sen_c['bp_face_url'].isna()]
# Out:
#          wmpid                      cand_name                 full_name  \
# 46   WMPID1644         HERNANDEZ, SALOMON SR.     Salomon Sr. Hernandez
# 49   WMPID3554            JOHNSON, ERIC CHASE        Eric Chase Johnson
# 59   WMPID3751   HAUSKINS, DANIEL OBAMA MR JR           Daniel Hauskins
# 62   WMPID2419  HORGES, BRADLEY LAMAR MR. JR.  Bradley Lamar Jr. Horges
# 71   WMPID2339               PARHAM, NICHOLAS           Nicholas Parham
# 73   WMPID4532       VICTORIAN, MICHAEL DUKES   Michael Dukes Victorian
# 81   WMPID4178               TUNNELL, LEONARD           Leonard Tunnell
# 95   WMPID4165            GRIFFIN, PETER JOHN        Peter John Griffin
# 96   WMPID2154             LOWE, GRETCHEN RAE         Gretchen Rae Lowe
# 130  WMPID3203        WISE MURRAY IV, WILLIAM    William Wise Murray Iv
# 131  WMPID3780                DIXON, NATE DR.                Nate Dixon
# 150  WMPID3887    D'AMICO, SAMUEL NICHOLAS MR   Samuel Nicholas D?Amico
#
#     cand_office_st cand_party_affiliation matches bp_name_raw bp_url bp_name  \
# 46              FL                      W     NaN         NaN    NaN     NaN
# 49              GA                    IND     NaN         NaN    NaN     NaN
# 59              IL                    GWP     NaN         NaN    NaN     NaN
# 62              IL                      W     NaN         NaN    NaN     NaN
# 71              LA                    IND     NaN         NaN    NaN     NaN
# 73              LA                    SLP     NaN         NaN    NaN     NaN
# 81              MO                    REP     NaN         NaN    NaN     NaN
# 95              NV                    COM     NaN         NaN    NaN     NaN
# 96              NV                    NPA     NaN         NaN    NaN     NaN
# 130             SC                    NaN     NaN         NaN    NaN     NaN
# 131             SC                    NPA     NaN         NaN    NaN     NaN
# 150             WI                    DEM     NaN         NaN    NaN     NaN
#
#     bp_url_filename  ... hc_face_note  hc_face_url hc_first_name hc_last_name  \
# 46              NaN  ...          NaN          NaN       Salomon    Hernandez
# 49              NaN  ...          NaN          NaN           NaN          NaN
# 59              NaN  ...          NaN          NaN           NaN          NaN
# 62              NaN  ...          NaN          NaN       Bradley        Horge
# 71              NaN  ...          NaN          NaN           NaN          NaN
# 73              NaN  ...          NaN          NaN           NaN          NaN
# 81              NaN  ...          NaN          NaN           NaN          NaN
# 95              NaN  ...          NaN          NaN           NaN          NaN
# 96              NaN  ...          NaN          NaN           NaN          NaN
# 130             NaN  ...          NaN          NaN       William       Murray
# 131             NaN  ...          NaN          NaN           NaN          NaN
# 150             NaN  ...          NaN          NaN        Samuel      D'Amico
#
#     hc_middle_name hc_suffix hc_affix hc_name_other  hc_double_surname  \
# 46             NaN       Sr.      NaN           NaN                NaN
# 49             NaN       NaN      NaN           NaN                NaN
# 59             NaN       NaN      NaN           NaN                NaN
# 62           Lamar       Jr.      NaN           NaN                NaN
# 71             NaN       NaN      NaN           NaN                NaN
# 73             NaN       NaN      NaN           NaN                NaN
# 81             NaN       NaN      NaN           NaN                NaN
# 95             NaN       NaN      NaN           NaN                NaN
# 96             NaN       NaN      NaN           NaN                NaN
# 130           Wise        IV      NaN           NaN                NaN
# 131            NaN       NaN      NaN           NaN                NaN
# 150       Nicholas       NaN      NaN           NaN                NaN
#
#     bp_face_url
# 46          NaN
# 49          NaN
# 59          NaN
# 62          NaN
# 71          NaN
# 73          NaN
# 81          NaN
# 95          NaN
# 96          NaN
# 130         NaN
# 131         NaN
# 150         NaN
#
# [12 rows x 21 columns]

# %%
url=sen_c[['wmpid', 'bp_face_url']]

# %% [markdown]
# ### Finalize face urls

# %%
df = s.merge(url, on='wmpid', how='left', indicator=True)

# %%
df._merge.value_counts()
# Out:
# both          172
# left_only       1
# right_only      0
# Name: _merge, dtype: int64

# %% [markdown]
# check the missing one from Jasmine's file
# - No face image: https://ballotpedia.org/Walter_Sluzynsky

# %%
df.loc[df._merge=='left_only']
# Out:
#          wmpid                    cand_name               full_name  \
# 125  WMPID2092  SLUZYNSKY, WALTER STEVE MR.  Walter Steve Sluzynsky
#
#     cand_office_st cand_party_affiliation bp_face_url     _merge
# 125             PA                    DEM         NaN  left_only

# %%
df.head()
# Out:
#        wmpid            cand_name           full_name cand_office_st  \
# 0  WMPID1299   BOOZMAN, SEN. JOHN        John Boozman             AR
# 1  WMPID1302          KELLY, MARK          Mark Kelly             AZ
# 2  WMPID1305   BENNET, MICHAEL F.      Michael Bennet             CO
# 3  WMPID1315  BLUMENTHAL, RICHARD  Richard Blumenthal             CT
# 4  WMPID1321         RUBIO, MARCO         Marco Rubio             FL
#
#   cand_party_affiliation                                        bp_face_url  \
# 0                    REP  https://s3.amazonaws.com/ballotpedia-api4/file...
# 1                    DEM  https://s3.amazonaws.com/ballotpedia-api4/file...
# 2                    DEM  https://s3.amazonaws.com/ballotpedia-api4/file...
# 3                    DEM  https://s3.amazonaws.com/ballotpedia-api4/file...
# 4                    REP  https://s3.amazonaws.com/ballotpedia-api4/file...
#
#   _merge
# 0   both
# 1   both
# 2   both
# 3   both
# 4   both

# %%
df.loc[df.bp_face_url.isna()]
# Out:
#          wmpid                      cand_name                 full_name  \
# 46   WMPID1644         HERNANDEZ, SALOMON SR.     Salomon Sr. Hernandez
# 49   WMPID3554            JOHNSON, ERIC CHASE        Eric Chase Johnson
# 59   WMPID3751   HAUSKINS, DANIEL OBAMA MR JR           Daniel Hauskins
# 62   WMPID2419  HORGES, BRADLEY LAMAR MR. JR.  Bradley Lamar Jr. Horges
# 71   WMPID2339               PARHAM, NICHOLAS           Nicholas Parham
# 73   WMPID4532       VICTORIAN, MICHAEL DUKES   Michael Dukes Victorian
# 81   WMPID4178               TUNNELL, LEONARD           Leonard Tunnell
# 95   WMPID4165            GRIFFIN, PETER JOHN        Peter John Griffin
# 96   WMPID2154             LOWE, GRETCHEN RAE         Gretchen Rae Lowe
# 125  WMPID2092    SLUZYNSKY, WALTER STEVE MR.    Walter Steve Sluzynsky
# 131  WMPID3203        WISE MURRAY IV, WILLIAM    William Wise Murray Iv
# 132  WMPID3780                DIXON, NATE DR.                Nate Dixon
# 151  WMPID3887    D'AMICO, SAMUEL NICHOLAS MR   Samuel Nicholas D?Amico
#
#     cand_office_st cand_party_affiliation bp_face_url     _merge
# 46              FL                      W         NaN       both
# 49              GA                    IND         NaN       both
# 59              IL                    GWP         NaN       both
# 62              IL                      W         NaN       both
# 71              LA                    IND         NaN       both
# 73              LA                    SLP         NaN       both
# 81              MO                    REP         NaN       both
# 95              NV                    COM         NaN       both
# 96              NV                    NPA         NaN       both
# 125             PA                    DEM         NaN  left_only
# 131             SC                    NaN         NaN       both
# 132             SC                    NPA         NaN       both
# 151             WI                    DEM         NaN       both

# %%
df['face_2022']='yes'

# %%
df['face_category']='senate_general'

# %%
df = df[['wmpid', 'bp_face_url', 'face_2022', 'face_category']]

# %%
df.shape
# Out:
# (173, 4)

# %%
df.head()
# Out:
#        wmpid                                        bp_face_url face_2022  \
# 0  WMPID1299  https://s3.amazonaws.com/ballotpedia-api4/file...       yes
# 1  WMPID1302  https://s3.amazonaws.com/ballotpedia-api4/file...       yes
# 2  WMPID1305  https://s3.amazonaws.com/ballotpedia-api4/file...       yes
# 3  WMPID1315  https://s3.amazonaws.com/ballotpedia-api4/file...       yes
# 4  WMPID1321  https://s3.amazonaws.com/ballotpedia-api4/file...       yes
#
#     face_category
# 0  senate_general
# 1  senate_general
# 2  senate_general
# 3  senate_general
# 4  senate_general

# %%
df=df.rename(columns={'bp_face_url':'face_url'})

# %%
df.to_csv("./data/face_url_2022_senate_general.csv", index=True)
