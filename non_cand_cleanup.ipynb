# %% [markdown]
# ## Non-candidate clean up

# %%
import pandas as pd

# %%
master = pd.read_csv("./person_2022_cd101222_v3.csv")

# %%
master.head()
# Out:
#        wmpid          full_name                       name_fec first_name  \
# 0     WMPID1         Mike Pence                    PENCE, MIKE       Mike
# 1    WMPID10       John Roberts                  ROBERTS, JOHN       John
# 2   WMPID100     Rebecca Keltie                KELTIE, REBECCA    Rebecca
# 3  WMPID1000    Josh Gottheimer               GOTTHEIMER, JOSH       Josh
# 4  WMPID1001  Bill Pascrell Jr.  PASCRELL, WILLIAM J. HON. JR.    Bill Jr
#
#     last_name gender_wmp fecid_2020 fecid_2022a fecid_2022b fecid_2022old  \
# 0       Pence          M        NaN         NaN         NaN           NaN
# 1     Roberts          M        NaN         NaN         NaN           NaN
# 2      Keltie          F  H0CO05152   H0CO05152         NaN           NaN
# 3  Gottheimer          M  H6NJ05171   H6NJ05171         NaN           NaN
# 4    Pascrell          M  H6NJ08118   H6NJ08118         NaN           NaN
#
#    ...  supcourt_2022 supcourt_former currsen_2022 prompol latino_wmp  \
# ...

# %%
master.columns
# Out:
# Index(['wmpid', 'full_name', 'name_fec', 'first_name', 'last_name',
#        'gender_wmp', 'fecid_2020', 'fecid_2022a', 'fecid_2022b',
#        'fecid_2022old', 'fecid_changed', 'crp_candidate_id', 'face_url',
#        'dateadded_person', 'notes_person', 'wmp_notes', 'genelect_cd_2022',
#        'supcourt_2022', 'supcourt_former', 'currsen_2022', 'prompol',
#        'latino_wmp', 'latino_crp', 'race_wmp', 'race_crp1', 'race_crp2',
#        'race_crpmena'],
#       dtype='object')

# %%
master['currsen_2022'].value_counts()
# Out:
# 0    5065
# 1     100
# Name: currsen_2022, dtype: int64

# %%
master.loc[(master['currsen_2022']==1)]
# Out:
#          wmpid         full_name             name_fec first_name   last_name  \
# 330  WMPID1296  Tommy Tuberville    TUBERVILLE, TOMMY      Tommy  Tuberville
# 333  WMPID1299      John Boozman   BOOZMAN, SEN. JOHN       John     Boozman
# 338  WMPID1302        Mark Kelly          KELLY, MARK      Kelly        Mark
# 340  WMPID1304  Dianne Feinstein    FEINSTEIN, DIANNE     Dianne   Feinstein
# 341  WMPID1305    Michael Bennet   BENNET, MICHAEL F.    Michael      Bennet
# ..         ...               ...                  ...        ...         ...
# 609  WMPID1547   Charles Schumer  SCHUMER, CHARLES E.    Charles     Schumer
# 610  WMPID1548      Jeff Merkley        MERKLEY, JEFF       Jeff     Merkley
# 611  WMPID1549  Marsha Blackburn    BLACKBURN, MARSHA     Marsha   Blackburn
# 613  WMPID1550       Mitt Romney         ROMNEY, MITT       Mitt      Romney
# 614  WMPID1551    Maria Cantwell      CANTWELL, MARIA      Maria    Cantwell
#
# ...

# %%
master.loc[(master['supcourt_2022']==1)]
# Out:
#           wmpid              full_name                name_fec     first_name  \
# 1       WMPID10           John Roberts           ROBERTS, JOHN           John
# 112     WMPID11        Clarence Thomas        THOMAS, CLARENCE       Clarence
# 334     WMPID13            Elena Kagan            KAGAN, ELENA          Elena
# 445     WMPID14        Sonia Sotomayor        SOTOMAYOR, SONIA          Sonia
# 556     WMPID15           Neil Gorsuch           GORSUCH, NEIL           Neil
# 667     WMPID16        Brett Kavanaugh        KAVANAUGH, BRETT          Brett
# 778     WMPID17            Amy Barrett            BARRETT, AMY            Amy
# 4629  WMPID5166  Ketanji Brown Jackson  JACKSON, KETANJI BROWN  Ketanji Brown
# 5054     WMPID9           Samuel Alito           ALITO, SAMUEL         Samuel
#
#       last_name gender_wmp fecid_2020 fecid_2022a fecid_2022b fecid_2022old  \
# 1       Roberts          M        NaN         NaN         NaN           NaN
# ...

# %%
master.loc[(master['supcourt_former']==1)]
# Out:
#         wmpid       full_name         name_fec first_name last_name  \
# 223   WMPID12  Stephen Breyer  BREYER, STEPHEN    Stephen    Breyer
# 889   WMPID18   Ruth Ginsburg   GINSBURG, RUTH       Ruth  Ginsburg
# 1000  WMPID19  Antonin Scalia  SCALIA, ANTONIN    Antonin    Scalia
#
#      gender_wmp fecid_2020 fecid_2022a fecid_2022b fecid_2022old  ...  \
# 223           M        NaN         NaN         NaN           NaN  ...
# 889           F        NaN         NaN         NaN           NaN  ...
# 1000          M        NaN         NaN         NaN           NaN  ...
#
#       supcourt_2022 supcourt_former currsen_2022 prompol latino_wmp  \
# 223               0             1.0            0       0        NaN
# 889               0             1.0            0       0        NaN
# 1000              0             1.0            0       0        NaN
#
#      latino_crp  race_wmp  race_crp1  race_crp2  race_crpmena
# 223         NaN       NaN        NaN        NaN           NaN
# ...
